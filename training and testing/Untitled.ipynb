# %%
import pandas as pd

# %%
df= pd.read_csv("carprices.csv")
df.head()
# Out:
#    Mileage  Age(yrs)  Sell Price($)
# 0    69000         6          18000
# 1    35000         3          34000
# 2    57000         5          26100
# 3    22500         2          40000
# 4    46000         4          31500

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(df["Mileage"],df["Sell Price($)"])
plt.xlabel("Mileage")  # X-axis label
plt.ylabel("Sell Price ($)")  # Y-axis label
plt.title("Car Mileage vs Selling Price")  # Plot title

plt.show()

# %%
plt.scatter(df["Age(yrs)"],df["Sell Price($)"])
plt.xlabel("Age(yrs)")  # X-axis label
plt.ylabel("Sell Price ($)")  # Y-axis label
plt.title("Car Mileage vs Selling Price")  # Plot title

plt.show()

# %%
X=df[["Age(yrs)","Mileage"]]
Y=df["Sell Price($)"]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, Y_train, Y_test= train_test_split(X,Y, test_size= 0.3)

# %%
len(X)
# Out:
# 20

# %%
len(X_test)
# Out:
# 6

# %%
len(X_train)
# Out:
# 14

# %%
X_test
# Out:
#     Age(yrs)  Mileage
# 5          5    59000
# 16         2    28000
# 8          8    91000
# 13         4    58780
# 17         5    69000
# 9          6    67000

# %%
from sklearn.linear_model import LinearRegression
clf= LinearRegression()
clf.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
#     Age(yrs)  Mileage
# 5          5    59000
# 16         2    28000
# 8          8    91000
# 13         4    58780
# 17         5    69000
# 9          6    67000

# %%
clf.predict(X_test)
# Out:
# array([25980.39570447, 37855.55131953, 13858.46075266, 27443.01921731,
#        23512.60233712, 22597.82895182])

# %%
Y_test
# Out:
# 5     26750
# 16    35500
# 8     12000
# 13    27500
# 17    19700
# 9     22000
# Name: Sell Price($), dtype: int64

# %%
clf.score(X_test,Y_test)
# Out:
# 0.9231045155191283
